# %% [markdown]
# <a href="https://colab.research.google.com/github/TharunLR/learning-python/blob/main/new_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("enter the first digit"))
#b=int(input("enter the second digit"))
def calculate(a):
  if (a%2==0):
    print("the digit is even!!!")
  else:
    print("the number is odd!!!")


calculate(a)
# Out:
# enter the first digit2
# the digit is even!!!

# %%
a=int(input("enter the first digit: "))
b=int(input("Enter the second digit: "))
def calculate(a,b):
  if (a>=b):
    print("The",a," greater than or equal to b",b)
  else:
    print("The ",a," is lesser than b",b)

calculate(a,b)
# Out:
# enter the first digit: 4
# Enter the second digit: 4
# The 4  greater than or equal to b 4

# %%
def average(*numbers):
  sum=0
  for i in numbers:
    sum=sum+i
  print("Average of :",sum/len(numbers))

average(5,15,2)
# Out:
# Average of : 7.333333333333333

# %%
def average(*numbers):
  sum=0
  for i in numbers:
    sum=sum+i
  #print("Average of :",sum/len(numbers))
  return sum/len(numbers)
a=int(input("Enter the digit A:"))
b=int(input("Enter the digit B:"))
c=int(input("Enter the digit C:"))
result=average(a,b,c)
print("THe average of result is : ",result)
# Out:
# Enter the digit A:2
# Enter the digit B:45
# Enter the digit C:0
# THe average of result is :  15.666666666666666
