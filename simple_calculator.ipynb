# %% [markdown]
# <a href="https://colab.research.google.com/github/TharunLR/learning-python/blob/main/simple_calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Example 1

# %%
# !git clone https://github.com/TharunLR/learning-python.git
# Out:
# Cloning into 'learning-python'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
a= 12
b= 2
add=a+b
print("addition of ",a ,"+ ",b,"is",add)
sub=a-b
print("substraction of ",a,"-",b,"is",sub)
mul=a*b
print("multiplication of ",a,"*",b,"is",mul)
# Out:
# addition of  12 +  2 is 14
# substraction of  12 - 2 is 10
# multiplication of  12 * 2 is 24

# %%
a=12
print(a)
a1=9.1
b="Thar"
print(b)
c=a+a1
print(a+a1)
print("The data type of a is",type(a))
print("the ",type(b))
print("the",type(c))
# Out:
# 12
# Thar
# 21.1
# The data type of a is <class 'int'>
# the  <class 'str'>
# the <class 'float'>

# %%
#taking user inputes
a=input("Enter your name")
print("your name is:",a)
b=input("Enter your Branch Name:")
c=int(input("Enter the marks of Last 5 sems :"))
d=float(input("Enter the cgpa of last sems:"))
print("\nThe information of the ",a,"is:")
print(b)
print(c)
print(d)
# Out:
# Enter your nameasdf
# your name is: asdf
# Enter your Branch Name:as
# Enter the marks of Last 5 sems :789
# Enter the cgpa of last sems:8.0
#
# The information of the  asdf is:
# as
# 789
# 8.0

# %%
a="1"
b="   a"
print(a+ b)
# Out:
# 1   a
